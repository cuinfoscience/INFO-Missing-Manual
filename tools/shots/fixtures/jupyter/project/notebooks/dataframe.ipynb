# %%
import pandas as pd

df = pd.DataFrame({
    "price":    [9.99, 14.50, 7.25, 22.00],
    "quantity": [3,    1,     2,    5],
    "in_stock": [True, True,  False, True],
}, index=["apple", "bread", "milk", "cheese"])

df

# %% [markdown]
# The labels down the left (`apple`, `bread`, …) are the **index**: row labels, not a column.
