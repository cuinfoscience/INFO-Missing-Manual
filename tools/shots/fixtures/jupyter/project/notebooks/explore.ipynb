# %% [markdown]
# # Weekly sales
#
# A first look at the raw export from the two stores, before any cleaning.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/sales.csv")
df.head()

# %% [markdown]
# ## What to check next
#
# Every row is one product at one store on one day. Next: parse the dates and add a **revenue** column (`units * price`).

# %%
df.shape
